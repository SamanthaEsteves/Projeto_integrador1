# %%
def boas_vindas():
    print("Este programa é responsável pelo controle de qualidade do ar e dos possíveis efeitos à saúde. ")
    print("É possível navegar entre as alternativas por meio de números. ")
    print("1 - Inserir amostras ")
    print("2 - Alterar amostras ")
    print("3 - Apagar amostras ")
    print("4 - Classificar amostras ")
    print("5 - Saída do sistema ")

def entrada_usuario():
    try:
        opcao = int(input("Insira o número para selecionar a opção! "))
    except ValueError:
        print("Insira somente números entre 1 e 5 ")
    else:
        if opcao == 1:
            inserir_amostras()
        elif opcao == 2:
            alterar_amorestras()
        elif opcao == 3:
            apagar_amostras()
        elif opcao == 4:
            classificar_amostras()
        elif opcao == 5:
            saida_sistema()

def inserir_amostras():
    print("Esta opção ainda não está disponível! Espere até a próxima atualização. ")

def alterar_amorestras():
    print("Esta opção ainda não está disponível! Espere até a próxima atualização. ")

def apagar_amostras():
    print("Esta opção ainda não está disponível! Espere até a próxima atualização. ")

def classificar_amostras():
    try:
        mp1o = float(input("O parêmetro das Partículas Inaláveis (MP1O): "))
        mp2 = float(input("O parêmetro das Partículas Inaláveis Finas (MP2): "))
        o3 = float(input("O parêmetro do Ozônio (O3): "))
        co = float(input("O parêmetro do Monóxido de Carbono (CO): "))
        no2 = float(input("O parêmetro do Dióxido de Nitrogênio (NO2): "))
        so2 = float(input("O parêmetro do Dióxido de Enxofre (SO2): "))
    except:
        print("Insira somente números nas variáveis. ")
    else:
        poluentes = {
        "MP1O" : [0, 50, 51, 100, 101, 150, 151, 250, 251, 2000],
        "MP2" : [0, 25, 26, 50, 51, 75, 76, 125, 126, 2000],
        "O3" : [0, 100, 101, 130, 131, 160, 161, 200, 201, 2000],
        "CO" : [0, 9, 10, 11, 12, 13, 14, 15, 15, 2000],
        "NO2" : [0, 200, 201, 240, 241, 320, 321, 1130, 1131, 2000],
        "SO2" : [0, 20, 21, 40, 41, 365, 366, 800, 801, 2000],
        }

        tabela = {
        "qualidade": ["Boa", "Moderada", "Ruim", "Muito ruim", "Péssima"],
        "significado": ["A qualidade do ar não afeta a qualidade de vida nem da população em geral, nem de grupos de pessoas sensíveis.", 
                        "Pessoas de grupos sensíveis (crianças, idosos e pessoas com doenças respiratórias e cardiacas) podem apresentar sintomas como tosse seca e cansaço. A população, em geral, não é afetada.",
                        "Toda a população pode apresentar sintomas como tosse seca, cansaço, ardor nos olhos, nariz e garganta. Pessoas de grupos sensíveis (crianças, idosos e pessoas com doenças resporatórias e cardíacas) podem apresentar efeitos mais sérios à saude.",
                        "Toda a população pode apresentar agravamento dos sintomas como tosse seca, cansaço, ardor nos olhos, nariz e garganta e ainda falta de ar e respiração ofegante. Efeitos ainda mais graves à saúde de grupos sensíveis (crianças, idosos e pessoas com doenças respiratórias e cardíacas).",
                        "Toda a população pode apresentar sérios riscos de manifestação de doenças respiratórias e cardiovasculares. Aumento de fortes prematuras em pessoas de grupos sensíveis."]
        }

        try:
            for n in range(10):
                if poluentes["MP1O"][n] <= mp1o < poluentes["MP1O"][n+1]:
                    vmp1O = n / 2
                if poluentes["MP2"][n] <= mp2 < poluentes["MP2"][n+1]:
                    vmp2 = n / 2
                if poluentes["O3"][n] <= o3 < poluentes["O3"][n+1]:
                    vo3 = n / 2
                if poluentes["CO"][n] <= co < poluentes["CO"][n+1]:
                    vco = n / 2
                if poluentes["NO2"][n] <= no2 < poluentes["NO2"][n+1]:
                    vno2 = n / 2
                if poluentes["SO2"][n] <= so2 < poluentes["SO2"][n+1]:
                    vso2 = n / 2

            lista = (vmp1O, vmp2, vo3, vco, vno2, vso2)
            vmax = int(max(lista))

            print(f'De acordo com os dados inseridos, a qualidade do ar é {tabela["qualidade"][vmax]}.')
            print(f'Sendo assim, temos que: {tabela["significado"][vmax]}')
        except:
            print("Ocorreu um erro!")

def saida_sistema():
    print("Obrigada por usar o sistema de controle de qualidade do ar, finalizando o programa! ")

boas_vindas()
entrada_usuario()
